# %%
import numpy as np
from tinygrad.helpers import Timing
from tinygrad import Tensor

# %%
t1 = Tensor([1, 2, 3, 4, 5])
print(t1)

t2 = Tensor([0, 1, 0, 1, 1])
t3 = t1 * t2
print(t3.numpy())
# Out:
# <Tensor <UOp METAL (5,) int (<Ops.COPY: 7>, None)> on METAL with grad None>
# [0 2 0 4 5]
